# %%
import boto3
import os

print("SageMaker Project Started!")
# Out:
# SageMaker Project Started!

# %%
import os

dataset_path = "/home/sagemaker-user/shared/dataset"

print("Dataset Path:", dataset_path)
print("Folders:", os.listdir(dataset_path))
# Out:
# Dataset Path: /home/sagemaker-user/shared/dataset
# Folders: ['cat', 'dog']

# %%
import os

cat_path = "/home/sagemaker-user/shared/dataset/cat"
dog_path = "/home/sagemaker-user/shared/dataset/dog"

print("Cat Images:", len(os.listdir(cat_path)))
print("Dog Images:", len(os.listdir(dog_path)))
# Out:
# Cat Images: 1
# Dog Images: 1

# %%
print("Cat Images:", len(os.listdir(cat_path)))
print("Dog Images:", len(os.listdir(dog_path)))
# Out:
# Cat Images: 10
# Dog Images: 10

# %%
# !pip install tensorflow pillow matplotlib

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    "/home/sagemaker-user/shared/dataset",
    image_size=(224, 224),
    batch_size=8
)

class_names = dataset.class_names
print("Classes:", class_names)
# Out:
# 2026-07-08 14:04:18.207175: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 18 files belonging to 2 classes.
# Classes: ['cat', 'dog']

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Conv2D(16, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(2)
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

history = model.fit(dataset, epochs=5)
# Out:
# Epoch 1/5
# 2026-07-08 14:05:21.388614: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25233408 exceeds 10% of free system memory.
# 2026-07-08 14:05:21.470999: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25233408 exceeds 10% of free system memory.
# 2026-07-08 14:05:21.487619: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25233408 exceeds 10% of free system memory.
# 2026-07-08 14:05:21.546542: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25233408 exceeds 10% of free system memory.
# 2026-07-08 14:05:21.568052: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25233408 exceeds 10% of free system memory.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 714ms/step - accuracy: 0.3889 - loss: 19.1538
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - accuracy: 0.3889 - loss: 5.6465
# Epoch 3/5
# ...

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img = load_img("/home/sagemaker-user/shared/Dog_PNG_Clip_Art_Image.png", target_size=(224,224))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

predicted_class = class_names[np.argmax(prediction)]

print("Prediction:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Prediction: cat

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img = load_img("/home/sagemaker-user/shared/Dog_PNG_Clip_Art_Image.png", target_size=(224,224))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

predicted_class = class_names[np.argmax(prediction)]

print("Prediction:", predicted_class)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 from tensorflow.keras.utils import load_img, img_to_array
#       2 import numpy as np
# ----> 4 img = load_img("/home/sagemaker-user/shared/Dog_PNG_Clip_Art_Image.png", target_size=(224,224))
#       5 img_array = img_to_array(img)
#       6 img_array = np.expand_dims(img_array, axis=0)
#
# File /opt/conda/lib/python3.12/site-packages/keras/src/utils/image_utils.py:247, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     245     if isinstance(path, pathlib.Path):
#     246         path = str(path.resolve())
# --> 247     with open(path, "rb") as f:
#     248         img = pil_image.open(io.BytesIO(f.read()))
#     249 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sagemaker-user/shared/Dog_PNG_Clip_Art_Image.png'

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

# Load the test image
img = load_img("/home/sagemaker-user/shared/images.jpg", target_size=(224, 224))

# Convert image to array
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

# Predict
prediction = model.predict(img_array)

# Get predicted class
predicted_class = class_names[np.argmax(prediction)]

print("Prediction:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Prediction: cat

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# Load test image
img = load_img("/home/sagemaker-user/shared/images.jpg", target_size=(224, 224))

# Convert image to array
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

# Predict
prediction = model.predict(img_array)

# Display prediction
predicted_class = class_names[np.argmax(prediction)]

print("Prediction:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Prediction: cat

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# Load the image
img = load_img("/home/sagemaker-user/shared/images.jpg", target_size=(224, 224))

# Convert image to array
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

# Predict
prediction = model.predict(img_array)

# Get predicted class
predicted_class = class_names[np.argmax(prediction)]

print("Prediction:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Prediction: cat
